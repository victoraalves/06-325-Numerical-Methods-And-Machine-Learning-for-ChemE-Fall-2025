# %% [markdown]
# # Homework 4 - Due Monday, September 29, 2025 11:59pm

# %% [markdown]
# ### Names of peers/colleages you collaborated with (if applicable):
#
# ### Generative AI statement (Please indicate if you used generative AI, where and how):

# %% [markdown]
# Exporting and Submitting Your Homework
#
# 0. Press ctrl + s (or command + s on a Mac) to save your notebook after you are done solving the assignment.
#
# 1.	Run the export commands at the end of this notebook to generate your HW as a PDF.
#
# 2.	Authenticate when prompted by selecting your Google account and allowing access.
#
# 3.	Wait a couple of minutes for the PDF to be generated and downloaded.
# 4.	Verify the PDF:
#
# -	Ensure no images, equations, or code are missing.
#
# -	To add images (e.g., handwritten work), use the Add Image option in a Google Colab text cell.
#
# 5.	Don't worry if equations from the problem statement are not perfectly compiled, as long as your answers are clear.
#
# 6.	Submit the final PDF to Canvas.

# %% [markdown]
# Adding an image:
#
# ![Screenshot 2025-08-27 at 8.05.28 PM.png](data:image/png;base64,...)

# %% [markdown]
# Considering the dataset uploaded to canvas, named as "logzsv.csv" from Lecture 8:

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("logzsv.csv", index_col=0)
df
# Out:
#            conc         zsv  log-conc   log-zsv
# ExptNo.
# 1          1.80    1.343571  0.587787  0.295331
# 2          7.50  470.248800  2.014903  6.153262
# 3         31.60    4.892228  3.453157  1.587648
# 4        133.40    9.687286  4.893352  2.270814
# 5        562.30    1.586862  6.332036  0.461759
# 6          3.16    1.385140  1.150572  0.325801
# 7          5.21    4.537974  1.650580  1.512481
# 8         11.02   57.865808  2.399712  4.058127
# 9         18.17    8.042775  2.899772  2.084774
# 10        60.34    7.768176  4.099995  2.050035
# 11         4.06    1.544971  1.401183  0.435005
# 12         8.05  537.217396  2.085672  6.286403
# 13        23.34    5.851642  3.150169  1.766722
# 14        94.63   11.911588  4.549975  2.477512
# 15       295.89    3.646146  5.689988  1.293671
# 16        43.82    5.809897  3.780090  1.759563

# %%
import matplotlib.pyplot as plt

X = np.array(df["log-conc"])[:, None]
y = np.array(df["log-zsv"])[:, None]

plt.plot(X, y, "ko", label="Training Data")
plt.legend()
plt.xlabel("X")
plt.ylabel("y")
# Out:
# Text(0, 0.5, 'y')

# %% [markdown]
# Generate:

# %% [markdown]
# ### 1. A Decision Tree with depth = 5

# %%
# ADD YOUR CODE HERE  -- feel free to add additional code or markdown blocks if needed

# %% [markdown]
# ### 2. A Neural Network with 2 Layers, Tanh activation function and 5 neurons each

# %%
# ADD YOUR CODE HERE  -- feel free to add additional code or markdown blocks if needed

# %% [markdown]
# ### 3. A Gaussian Process with the RBF function (Alpha parameter in the `GaussianProcessRegressor` set to 0.1)

# %%
# ADD YOUR CODE HERE  -- feel free to add additional code or markdown blocks if needed

# %% [markdown]
# # Notes for all items above:
#
# - Use 80/20 train/test splits with `random_state=23`.
# - Use sklearn to generate these ML models.
# - Plot both the training and validation data against the model predictions (by creating new $x$ values between $x_{min}$ and $x_{max}$ based on training data),
# - Plot the hold-out validation plot (predicted vs. true values) for each item/ML model.

# %% [markdown]
# ## End of homework.

# %% [markdown]
# ## Run the code below to export your HW as a PDF:

# %% [markdown]
# !pip install pycse &> /dev/null

# %%
from pycse.colab import pdf

# %%
# %pdf -h
