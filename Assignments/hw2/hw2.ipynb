# %% [markdown]
# # Homework 2 - Due Wednesday, September 10, 2025 11:59pm

# %% [markdown]
# ## Names of peers/colleages you collaborated with (if applicable):
#
# ## Generative AI statement (Please indicate if you used generative AI, where and how):

# %% [markdown]
# Exporting and Submitting Your Homework
#
# 0. Press ctrl + s (or command + s on a Mac) to save your notebook after you are done solving the assignment.
#
# 1.	Run the export commands at the end of this notebook to generate your HW as a PDF.
#
# 2.	Authenticate when prompted by selecting your Google account and allowing access.
#
# 3.	Wait a couple of minutes for the PDF to be generated and downloaded.
# 4.	Verify the PDF:
#
# -	Ensure no images, equations, or code are missing.
#
# -	To add images (e.g., handwritten work), use the Add Image option in a Google Colab text cell.
#
# 5.	Don't worry if equations from the problem statement are not perfectly compiled, as long as your answers are clear.
#
# 6.	Submit the final PDF to Canvas.

# %% [markdown]
# Adding an image:
#
# ![Screenshot 2025-08-27 at 8.05.28 PM.png](data:image/png;base64,...)

# %% [markdown]
# ## 1. The Colebrook equation
#
# We can determine the friction factor $f$ of a pipe considering an incompressible fluid under turbulent flow via the Colebrook equation:
#
# $\sqrt{\frac{1}{f}}=-2 \log \left(\frac{\varepsilon / D}{3.7}+\frac{2.51}{\operatorname{Re} \sqrt{f}}\right)$
#
# In which $D$ is the inner diameter of the tube/pipe, $\varepsilon$ is the roughness and $Re$ the Reynolds number. Based on this. Assume you are given the following information: The relative roughness, defined as $\varepsilon/D$, is $10^{-3}$ and the Reynolds number $Re = 5\times10^6$. Please answer the following:
#
#
# a) Can this problem be solved analytically? Why or why not?
#
# b) What is (or are) the appropriate numerical method (or methods) suitable to solve this problem? Classify the method in terms of single vs. multivariate, as well as linear vs. nonlinear.
#
# c) Based on answer on (b), choose one numerical method to solve this problem. Clearly state the problem you are solving and how you will solve it, as well as tolerances used in your code and your solution. You can use functions from scipy. If you want to use your own functions and have chosen an open method, please remember that you need a way to evaluate derivatives. Initial estimate should be 0.01 for open-methods and [1e-3, 0.03] for a bracketing method.
#
# d) If you change the relative roughness to $10^{-6}$, what happens? Is this expected?
#
# e) Generate a plot of $Re$ ($x$ axis) vs friction factor $f$ for different relative roughness values. Use matplotlib's [semilogx](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.semilogx.html) plotting functionality to build this plot.
#
# Note: The colebrook equation is only valid for turbulent flow (e.g.,$Re \geq 4000$ for this correlation)

# %%
# ADD YOUR CODE HERE  -- feel free to add additional code or markdown blocks if needed

# %%
# ADD YOUR CODE HERE  -- feel free to add additional code or markdown blocks if needed

# %% [markdown]
# ## 2. Systems of Nonlinear Equations
#
# For all items, determine the solution of the systems given. This involves determining the residual function, the Jacobian, and the solution using both newton's method and scipy.optimize.root:
#
#
#
# a)
#
#
# $ e^{-2x_1} = 5x_2 $
#
# $x_1 + x_2 ^3 = 3x_2$
#
#
# b)
#
#
# $ sin(x_1) = e^{x_2} - 0.32 $
#
# $x_1 + x_2^3= 0$

# %%
# ADD YOUR CODE HERE  -- feel free to add additional code or markdown blocks if needed

# %% [markdown]
# ## 3. Curve fitting - Determining the kinetic constant from optimization using experiments

# %% [markdown]
# Let's reconsider the example seen in class for curve fitting. But instead of a first-order reaction, you should assume a *second* order reaction, and the following new data is presented to you:

# %% [markdown]
# $time = [0,  0.5, 1, 1.5, 2,  3,  4,  5] \,\,[h]$
#
# $C(t) = [1.05071577, 0.67567705, 0.52730039, 0.4377574,  0.33347517, 0.27033224, 0.21736459, 0.12917645]$

# %% [markdown]
# If we are considering a second order kinetic model, we have the following equation:
#
#
# $$C(t) = \frac{C_0}{(1 + kC_0 t)}$$
#
# in which $C_0$ is the initial concentration ($1 mol/l$), and $k$ is the kinetic constant $[L/mol h]$.

# %% [markdown]
# Considering this, answer the following:
#
#
# a) Plot $t \, vs. \, C(t)$.
#
# b) Write down the optimization problem that defines this curve fitting/parameter estimation problem for $k$.
#
# c) Solve this problem using scipy.optimize.minimize. You don't need to supply a hessian or derive one.
#
# d) Plot the experimental data $vs.$ the model prediction using the value of $k$ estimated via optimization. How good is the curve generate using the regressed value of $k$?

# %%
# ADD YOUR CODE HERE  -- feel free to add additional code or markdown blocks if needed
