# %% [markdown]
# # Homework 1 - Due Wednesday, September 3, 2025 11:59pm

# %% [markdown]
# ## Names of peers/colleages you collaborated with (if applicable):
#
# ## Generative AI statement (Please indicate if you used generative AI, where and how):

# %% [markdown]
# Exporting and Submitting Your Homework
#
# 0. Press ctrl + s (or command + s on a Mac) to save your notebook after you are done solving the assignment.
#
# 1.	Run the export commands at the end of this notebook to generate your HW as a PDF.
#
# 2.	Authenticate when prompted by selecting your Google account and allowing access.
#
# 3.	Wait a couple of minutes for the PDF to be generated and downloaded.
# 4.	Verify the PDF:
#
# -	Ensure no images, equations, or code are missing.
#
# -	To add images (e.g., handwritten work), use the Add Image option in a Google Colab text cell.
#
# 5.	Don't worry if equations from the problem statement are not perfectly compiled, as long as your answers are clear.
#
# 6.	Submit the final PDF to Canvas.

# %% [markdown]
# Adding an image:
#
# ![Screenshot 2025-08-27 at 8.05.28 PM.png](data:image/png;base64,...)

# %% [markdown]
# # 1) Python basics and linear systems

# %% [markdown]
# ## 1.1) Solve the following linear system:
#
# $$
# A=\left[\begin{array}{ccc}
# 3 & -0.1 & -0.2 \\
# 0.1 & 7 & -0.3 \\
# 0.3 & -0.2 & 10
# \end{array}\right], \quad b =\left[\begin{array}{l}
# 1 \\
# 2 \\
# 3
# \end{array}\right]
# $$

# %% [markdown]
# Check if a solution is viable in the first place. If it is, solve it using Python.

# %%
# ADD YOUR CODE HERE -- Feel free to add markdown cells to add written text if desired

# %% [markdown]
# ## 1.2) 50 kg/s of Methane, 25 kg/s of Ethane, and 10 kg/s of Propane. This mixture is separated in a distillation column into three streams: A distillate that is rich in Methane (92%) and some amount of ethane (8%), a middle stream that contains Ethane (65%) and the bottoms stream which contains mostly propane (80%). Determine the flow rates of the distillate, bottoms and side stream using Python. Print each flow rate individually with 3 decimal places. Please see the schematic below:

# %% [markdown]
# ![hw1_dist.png](data:image/png;base64,...)

# %%
# ADD YOUR CODE HERE  -- feel free to add additional code or markdown blocks if needed

# %% [markdown]
# # 2) Determine the residual function $F(x)$ and the Jacobian of:
#
# ## a)
#
# $$
# 2x_1^4+x_2^2 = 5 \\
# x_1^2 + x_2^2 = 2x_1
# $$

# %% [markdown]
# Feel free to write your answers in a Markdown cell in equation format. You may also upload a picture your your handwritten work here.

# %% [markdown]
# ## b)
#
#
# $$
# x_1 x_2 x_3 - x_1^2 + x_2^2 = sin(\alpha) \\
# 2\gamma = x_1 x_2 - x_3^2  \\
# e^{x_1} + x_2 = sin(x_3)
# $$

# %% [markdown]
# Add your answers here.

# %% [markdown]
# # 3) The Ergun Equation
#
# The Ergun equation provides a relationship between pressure drop across a packed bed per unit length and properties of the fluid. It is an important correlation in equipment design as it can predict pressure drop across vessels with increased accuracy when compared against not considering the fact that the vessel will have some sort of packing.
#
# This equation is given as:
#
# $$
#
# \frac{\Delta P}{L}=150\left(\frac{\eta v_0}{D_p^2}\right) \frac{(1-\epsilon)^2}{\epsilon^3}+\frac{7}{4}\left(\frac{\rho v_0^2}{D_p}\right) \frac{1-\epsilon}{\epsilon^3}
#
# $$
#
# where $\eta$ is the fluid viscosity, $v_o$ is the superficial velocity, $D_p$ is the particle diameter, $\rho$ is the fluid density, and $\epsilon$ is the void fraction of the bed. Consider a $1.5 \,m$ long packed bed containing $5 \, cm$ diameter particles. Fluid of density $2 \, g/cm^3$ and viscosity $1 \, cP$ flows through this bed at a superficial velocity of $0.1 \, m/s$. The pressure drop in the bed is $416 \, Pa$.

# %% [markdown]
# **a) Write down the equation in residual form here and the derivative of this expression. Clearly state the problem you are trying to solve with your own words. List which variables are inputs and outputs to this problem, as well as the parameters. (Hint, it is always a good idea to try to "translate" the problem into a canonical form, such as $f(\epsilon)=0$ + always check your units)**

# %% [markdown]
# Add your answer here.

# %% [markdown]
# **b) Write code that uses Bisection to solve this problem. Show the solution found (void fraction $\epsilon$), the number of iterations and the value of $|f(x)|$**

# %%
# ADD YOUR CODE HERE -- feel free to add multiple code blocks to organize your code

# %% [markdown]
# **c) Now, solve it using Newton's method to determine the void fraction of the bed $\epsilon$, the number of iterations and the value of $|f(x)|$.**

# %%
# ADD CODE HERE -- feel free to add additional code blocks to organize your code

# %% [markdown]
# **d) Check your solution using [scipy's newton's method](https://docs.scipy.org/doc/scipy/reference/generated/scipy.optimize.newton.html): (remember to provide the derivative function). Are these results close?**

# %%
# ADD YOUR CODE HERE

# %% [markdown]
# ## End of homework.

# %% [markdown]
# ## Run the code below to export your HW as a PDF:

# %%
# !pip install pycse &> /dev/null

# %%
from pycse.colab import pdf

# %%
# %pdf -h
